# %% [markdown]
# <a href="https://colab.research.google.com/github/suzannefox/burrow/blob/main/burrow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
pip install palmerpenguins
# Out:
# Requirement already satisfied: palmerpenguins in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from palmerpenguins) (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from palmerpenguins) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->palmerpenguins) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->palmerpenguins) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->palmerpenguins) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->palmerpenguins) (1.16.0)

# %%
import pandas as pd
import numpy as np
from palmerpenguins import load_penguins

# %%
# Supporting Functions

# return excel col equivalent of a numerical value
def excelcol(number):
  if number > 16384: return '16384 max'
  if number < 1: return 'must be > 0'

  letters = ""
  while number:
    number, remainder = divmod(number - 1, 26)
    letters = chr(65 + remainder) + letters

  return letters

# Define the function to return minimum value for numeric columns or first alphabetical occurrence for string columns
def custom_min(variable):
  if pd.api.types.is_numeric_dtype(variable.dropna()):
    return variable.dropna().min()  # Drop NaNs and get the minimum value
  elif pd.api.types.is_string_dtype(variable.dropna()):
    return variable.dropna().sort_values(ascending=True).reset_index(drop=True)[0]  # Sort descending and get the first value
  else:
    return None

# Define the function to return minimum value for numeric variables or first alphabetical occurrence for string variables
def custom_max(variable):
  if pd.api.types.is_numeric_dtype(variable.dropna()):
    return variable.dropna().max()  # Drop NaNs and get the minimum value
  elif pd.api.types.is_string_dtype(variable.dropna()):
    return variable.dropna().sort_values(ascending=False).reset_index(drop=True)[0]  # Sort and get the first alphabetical value
  else:
    return None

# return mean if a variable is numeric, - otherwise
def custom_mean(variable):
  if pd.api.types.is_numeric_dtype(variable.dropna()):
    return variable.dropna().mean().round(1)
  else:
    return '-'

# return skew if a variable is numeric, - otherwise
def custom_skew(variable):
  if pd.api.types.is_numeric_dtype(variable.dropna()):
    return variable.dropna().skew().round(1)
  else:
    return '-'

# determine a more explicit data type
def custom_type(variable):
  if pd.api.types.is_numeric_dtype(variable.dropna()):
    return('numeric')
  elif pd.api.types.is_string_dtype(variable.dropna()):
    return('string')
  elif pd.api.types.is_bool_dtype(variable.dropna()):
    return('bool')
  elif pd.api.types.is_datetime64_dtype(variable.dropna()):
    return('datetime')
  elif pd.api.types.is_object_dtype(variable.dropna()):
    return('object')
  elif pd.api.types.is_integer_dtype(variable.dropna()):
    return('integer')
  elif pd.api.types.is_float_dtype(variable.dropna()):
    return('float')
  elif pd.api.types.is_categorical_dtype(variable.dropna()):
    return('categorical')
  elif pd.api.types.is_sparse_dtype(variable.dropna()):
    return('sparse')
  elif pd.api.types.is_generic_dtype(variable.dropna()):
    return('generic')
  elif pd.api.types.is_complex_dtype(variable.dropna()):
    return('complex')
  else:
    return None

# %%
def dfinfo(df, catalog=None, diagnostics=False, verbose=True):

  if df.empty:
    print('... dataframe is empty')
    return

  if verbose:
    df_name = [name for name in globals() if globals()[name] is df][0]
    print(f'... dataframe {df_name} has {df.shape[0]} records and {df.shape[1]} variables')

  # Main Body
  dfout = pd.DataFrame({'Variables': df.columns})

  dfout['Order'] = range(1, df.shape[1] + 1)
  dfout['Excel'] = dfout['Order'].apply(excelcol)

  if catalog is not None:
    if 'Variables' not in catalog.columns:
      print(" ... WARNING: catalog dataframe missing a 'Variables' column, ignoring")
    else:
      dfout = dfout.merge(catalog, on='Variables', how='left').fillna('')

  dfout['Class'] = df.dtypes.astype(str).values
  dfout['Type'] = df.apply(custom_type).reset_index(drop=True)

  dfout['NA_Tot'] = df.isna().sum().reset_index(drop=True)
  dfout['NA_PC'] = (df.isna().sum().reset_index(drop=True) / len(df) * 100).apply(lambda x: f"{x:.0f}%")

  dfout['Unique_Tot'] = df.nunique().reset_index(drop=True)
  dfout['Unique_PC'] = (df.nunique().reset_index(drop=True) / len(df) * 100).apply(lambda x: f"{x:.0f}%")

  # Calculate min for numeric columns only
  dfout['Min'] = df.apply(custom_min).reset_index(drop=True)
  # Calculate max for numeric columns only
  dfout['Max'] = df.apply(custom_max).reset_index(drop=True)

  dfout['Mean'] = df.apply(custom_mean).reset_index(drop=True)
  dfout['Skew'] = df.apply(custom_skew).reset_index(drop=True)

  return dfout

# %% [markdown]
# # mount local drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %% [markdown]
# # Penguins

# %%
penguins = load_penguins()

# %%
catalog = pd.DataFrame({'Variables': ['species','sex','island'],
                        'catalog': ['Penguin Species','Gender','Island they live on']})
dfinfo(penguins, catalog = catalog)
# Out:
# ... dataframe penguins has 344 records and 8 variables
#            Variables  Order Excel              catalog    Class     Type  \
# 0            species      1     A      Penguin Species   object   string
# 1             island      2     B  Island they live on   object   string
# 2     bill_length_mm      3     C                       float64  numeric
# 3      bill_depth_mm      4     D                       float64  numeric
# 4  flipper_length_mm      5     E                       float64  numeric
# 5        body_mass_g      6     F                       float64  numeric
# 6                sex      7     G               Gender   object   string
# 7               year      8     H                         int64  numeric
#
#    NA_Tot NA_PC  Unique_Tot Unique_PC     Min        Max    Mean Skew
# 0       0    0%           3        1%  Adelie     Gentoo       -    -
# 1       0    0%           3        1%  Biscoe  Torgersen       -    -
# 2       2    1%         164       48%    32.1       59.6    43.9  0.1
# 3       2    1%          80       23%    13.1       21.5    17.2 -0.1
# 4       2    1%          55       16%   172.0      231.0   200.9  0.3
# 5       2    1%          94       27%  2700.0     6300.0  4201.8  0.5
# 6      11    3%           2        1%  female       male       -    -
# 7       0    0%           3        1%    2007       2009  2008.0 -0.1

# %% [markdown]
# # Alzheimers data

# %%
dfalz = pd.read_csv('/gdrive/MyDrive/data/alzheimer_data.csv')
dfinfo(dfalz)
# Out:
# ... dataframe dfalz has 284142 records and 31 variables
#                      Variables  Order Excel    Class     Type  NA_Tot NA_PC  \
# 0                        RowId      1     A   object   string       0    0%
# 1                    YearStart      2     B    int64  numeric       0    0%
# 2                      YearEnd      3     C    int64  numeric       0    0%
# 3                 LocationAbbr      4     D   object   string       0    0%
# 4                 LocationDesc      5     E   object   string       0    0%
# 5                   Datasource      6     F   object   string       0    0%
# 6                        Class      7     G   object   string       0    0%
# 7                        Topic      8     H   object   string       0    0%
# 8                     Question      9     I   object   string       0    0%
# 9              Data_Value_Unit     10     J   object   string       0    0%
# 10             DataValueTypeID     11     K   object   string       0    0%
# 11             Data_Value_Type     12     L   object   string       0    0%
# 12                  Data_Value     13     M  float64  numeric   91334   32%
# 13              Data_Value_Alt     14     N  float64  numeric   91334   32%
# 14  Data_Value_Footnote_Symbol     15     O   object   string  174166   61%
# 15         Data_Value_Footnote     16     P   object   string  174166   61%
# 16        Low_Confidence_Limit     17     Q  float64  numeric   91545   32%
# 17       High_Confidence_Limit     18     R  float64  numeric   91545   32%
# 18     StratificationCategory1     19     S   object   string       0    0%
# 19             Stratification1     20     T   object   string       0    0%
# 20     StratificationCategory2     21     U   object   string   36873   13%
# 21             Stratification2     22     V   object   string   36873   13%
# 22                 Geolocation     23     W   object   string   30489   11%
# 23                     ClassID     24     X   object   string       0    0%
# 24                     TopicID     25     Y   object   string       0    0%
# 25                  QuestionID     26     Z   object   string       0    0%
# 26                  LocationID     27    AA    int64  numeric       0    0%
# 27   StratificationCategoryID1     28    AB   object   string       0    0%
# 28           StratificationID1     29    AC   object   string       0    0%
# 29   StratificationCategoryID2     30    AD   object   string       0    0%
# 30           StratificationID2     31    AE   object   string       0    0%
#
#     Unique_Tot Unique_PC                                                Min  \
# 0        36046       13%            BRFSS~2015~2015~01~Q01~TNC01~AGE~GENDER
# 1            8        0%                                               2015
# 2            8        0%                                               2015
# 3           59        0%                                                 AK
# 4           59        0%                                            Alabama
# 5            1        0%                                              BRFSS
# 6            7        0%                                         Caregiving
# 7           39        0%                       Arthritis among older adults
# 8           39        0%  Average of 20 or more hours of care per week p...
# 9            2        0%                                                  %
# 10           2        0%                                               MEAN
# 11           2        0%                                               Mean
# 12        1001        0%                                                0.0
# 13        1001        0%                                                0.0
# 14           5        0%                                                  #
# 15           5        0%  Estimate is not comparable to those generated ...
# 16         995        0%                                               -0.7
# 17         988        0%                                                1.3
# 18           1        0%                                          Age Group
# 19           3        0%                                        50-64 years
# 20           2        0%                                             Gender
# 21           7        0%                             Asian/Pacific Islander
# 22          54        0%                    POINT (-100.118421 47.47531978)
# 23           7        0%                                                C01
# 24          39        0%                                              TAC01
# 25          39        0%                                                Q01
# 26          59        0%                                                  1
# 27           1        0%                                                AGE
# 28           3        0%                                               5064
# 29           3        0%                                             GENDER
# 30           8        0%                                                ASN
#
#                                                   Max    Mean Skew
# 0             BRFSS~2022~2022~9004~Q46~TOC10~AGE~RACE       -    -
# 1                                                2022  2018.6 -0.1
# 2                                                2022  2018.7 -0.1
# 3                                                  WY       -    -
# 4                                             Wyoming       -    -
# 5                                               BRFSS       -    -
# 6                             Smoking and Alcohol Use       -    -
# 7   Up-to-date with recommended vaccines and scree...       -    -
# 8   Severe joint pain due to arthritis among older...       -    -
# 9                                              Number       -    -
# 10                                              PRCTG       -    -
# 11                                         Percentage       -    -
# 12                                              100.0    37.7  0.5
# 13                                              100.0    37.7  0.5
# 14                                                  ~       -    -
# 15  Sample size of denominator and/or age group fo...       -    -
# 16                                               99.6    33.0  0.7
# 17                                              100.0    42.6  0.4
# 18                                          Age Group       -    -
# 19                                            Overall       -    -
# 20                                     Race/Ethnicity       -    -
# 21                                White, non-Hispanic       -    -
# 22                       POINT (144.793731 13.444304)       -    -
# 23                                                C07       -    -
# 24                                              TSC11       -    -
# 25                                                Q46       -    -
# 26                                               9004   800.3  3.0
# 27                                                AGE       -    -
# 28                                        AGE_OVERALL       -    -
# 29                                               RACE       -    -
# 30                                                WHT       -    -

# %% [markdown]
# # Housing data

# %%
dfhou = pd.read_csv('/gdrive/MyDrive/data/housing.csv')
dfinfo(dfhou)
# Out:
# ... dataframe dfhou has 1460 records and 81 variables
#         Variables  Order Excel    Class     Type  NA_Tot NA_PC  Unique_Tot  \
# 0              Id      1     A    int64  numeric       0    0%        1460
# 1      MSSubClass      2     B    int64  numeric       0    0%          15
# 2        MSZoning      3     C   object   string       0    0%           5
# 3     LotFrontage      4     D  float64  numeric     259   18%         110
# 4         LotArea      5     E    int64  numeric       0    0%        1073
# ..            ...    ...   ...      ...      ...     ...   ...         ...
# 76         MoSold     77    BY    int64  numeric       0    0%          12
# 77         YrSold     78    BZ    int64  numeric       0    0%           5
# 78       SaleType     79    CA   object   string       0    0%           9
# 79  SaleCondition     80    CB   object   string       0    0%           6
# 80      SalePrice     81    CC    int64  numeric       0    0%         663
#
#    Unique_PC      Min      Max      Mean  Skew
# 0       100%        1     1460     730.5   0.0
# 1         1%       20      190      56.9   1.4
# 2         0%  C (all)       RM         -     -
# 3         8%     21.0    313.0      70.0   2.2
# 4        73%     1300   215245   10516.8  12.2
# ..       ...      ...      ...       ...   ...
# 76        1%        1       12       6.3   0.2
# 77        0%     2006     2010    2007.8   0.1
# 78        1%      COD       WD         -     -
# 79        0%  Abnorml  Partial         -     -
# 80       45%    34900   755000  180921.2   1.9
#
# [81 rows x 13 columns]
